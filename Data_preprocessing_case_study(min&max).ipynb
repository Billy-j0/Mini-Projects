# %% [markdown]
# # Importing libraries and reading dataset

# %%
# Importing libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Reading dataset

df = pd.read_csv(r"C:\Users\User\Desktop\titanic_dataset.csv")

# %%
# Displaying the first few rows

df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# Making ‘PassengerId’ as the index column.

df = df.set_index('PassengerId')
df
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
# Concise summary of dataset

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 1 to 891
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Name      891 non-null    object
#  3   Sex       891 non-null    object
#  4   Age       714 non-null    float64
#  5   SibSp     891 non-null    int64
#  6   Parch     891 non-null    int64
#  7   Ticket    891 non-null    object
#  8   Fare      891 non-null    float64
#  9   Cabin     204 non-null    object
#  10  Embarked  889 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 83.5+ KB

# %%
# Data types of dataset

df.dtypes
# Out:
# Survived      int64
# Pclass        int64
# Name         object
# Sex          object
# Age         float64
# SibSp         int64
# Parch         int64
# Ticket       object
# Fare        float64
# Cabin        object
# Embarked     object
# dtype: object

# %%
# Statistical summary of dataset

df.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
# Checking for missing values

df.isna().sum()
# Out:
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Cabin       687
# Embarked      2
# dtype: int64

# %%
df.isna().sum().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# **Insight : As can we see the columns Age contains 177 null values, cabin 687 null values and embarked contains 2 null values**
# <br> **But as we can see more than 77 percent of the data in 'cabin' is missing, so I think we can drop the 'cabin' feature**

# %%
# Filling up the data

df['Age']=df['Age'].fillna(df['Age'].median())
df['Embarked']=df['Embarked'].fillna(df['Embarked'].mode()[0])

# %%
# Dropping the 'Cabin' feature

df.drop('Cabin',axis=1,inplace=True)

# %%
df
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
# Checking the shape of the data

df.shape
# Out:
# (891, 10)

# %%
df.plot(kind='box',subplots=True,figsize=(12,12),layout=(5,3))
# Out:
# Survived       AxesSubplot(0.125,0.749828;0.227941x0.130172)
# Pclass      AxesSubplot(0.398529,0.749828;0.227941x0.130172)
# Age         AxesSubplot(0.672059,0.749828;0.227941x0.130172)
# SibSp          AxesSubplot(0.125,0.593621;0.227941x0.130172)
# Parch       AxesSubplot(0.398529,0.593621;0.227941x0.130172)
# Fare        AxesSubplot(0.672059,0.593621;0.227941x0.130172)
# dtype: object

# %% [markdown]
# **Insight : We can see outliers in 'Age', 'SibSp', 'Parch, 'Fare' features, we going to remove oultiers from 'Age', 'SibSp' and 'Fare'**

# %% [markdown]
# ## **Age**

# %%
# Calculating percentiles

Q1 =  np.percentile(df['Age'],25,interpolation='midpoint')
Q2 = np.percentile(df['Age'],50,interpolation='midpoint')
Q3 = np.percentile(df['Age'],75,interpolation='midpoint')
print('Q1 = ',Q1,'\nQ2 = ',round(Q2,2),'\nQ3 = ',Q3)
# Out:
# Q1 =  22.0
# Q2 =  28.0
# Q3 =  35.0

# %%
# Calculating inter quartile range

IQR=Q3-Q1
print('IQR = ',IQR)

# Calculating the upper and lower limit
low_lim=Q1-(1.5*IQR)
up_lim=Q3+(1.5*IQR)
print('Upper limit = ',up_lim,'\nLower limit = ',low_lim)
# Out:
# IQR =  13.0
# Upper limit =  54.5
# Lower limit =  2.5

# %%
# Creating a list of outliers

outl=[]
for x in df['Age']:
    if (x>up_lim or x<low_lim):
        outl.append(x)
outl
# Out:
# [2.0,
#  58.0,
#  55.0,
#  2.0,
#  66.0,
#  65.0,
#  0.83,
#  59.0,
#  71.0,
#  70.5,
#  2.0,
#  55.5,
#  1.0,
#  61.0,
#  1.0,
#  56.0,
#  1.0,
#  58.0,
#  2.0,
#  59.0,
#  62.0,
#  58.0,
#  63.0,
#  65.0,
#  2.0,
#  0.92,
#  61.0,
#  2.0,
#  60.0,
#  1.0,
#  1.0,
#  64.0,
#  65.0,
#  56.0,
#  0.75,
#  2.0,
#  63.0,
#  58.0,
#  55.0,
#  71.0,
#  2.0,
#  64.0,
#  62.0,
#  62.0,
#  60.0,
#  61.0,
#  57.0,
#  80.0,
#  2.0,
#  0.75,
#  56.0,
#  58.0,
#  70.0,
#  60.0,
#  60.0,
#  70.0,
#  0.67,
#  57.0,
#  1.0,
#  0.42,
#  2.0,
#  1.0,
#  62.0,
#  0.83,
#  74.0,
#  56.0]

# %%
# Finding index values of outliers

df.loc[(df['Age']>up_lim ) | (df['Age']<low_lim)].index
# Out:
# Int64Index([  8,  12,  16,  17,  34,  55,  79,  95,  97, 117, 120, 153, 165,
#             171, 173, 175, 184, 196, 206, 233, 253, 269, 276, 281, 298, 306,
#             327, 341, 367, 382, 387, 439, 457, 468, 470, 480, 484, 488, 493,
#             494, 531, 546, 556, 571, 588, 626, 627, 631, 643, 645, 648, 660,
#             673, 685, 695, 746, 756, 773, 789, 804, 825, 828, 830, 832, 852,
#             880],
#            dtype='int64', name='PassengerId')

# %%
# Removing the outliers

df.drop([ 8,  12,  16,  17,  34,  55,  79,  95,  97, 117, 120, 153, 165,
            171, 173, 175, 184, 196, 206, 233, 253, 269, 276, 281, 298, 306,
            327, 341, 367, 382, 387, 439, 457, 468, 470, 480, 484, 488, 493,
            494, 531, 546, 556, 571, 588, 626, 627, 631, 643, 645, 648, 660,
            673, 685, 695, 746, 756, 773, 789, 804, 825, 828, 830, 832, 852,
            880],inplace=True)

# %%
# Boxplot of 'Age' after removing outliers

plt.boxplot(df['Age'])
plt.show()

# %% [markdown]
# **Insight : 66 rows were removed from the dataset**

# %% [markdown]
# ## **SibSp**

# %%
# Calculating percentiles

Q1 = np.percentile(df['SibSp'],25,interpolation='midpoint')
Q2 = np.percentile(df['SibSp'],50,interpolation='midpoint')
Q3 = np.percentile(df['SibSp'],75,interpolation='midpoint')
print('Q1 = ',Q1,'\nQ2 = ',round(Q2,2),'\nQ3 = ',Q3)
# Out:
# Q1 =  0.0
# Q2 =  0.0
# Q3 =  1.0

# %%
# Calculating inter quartile range

IQR=Q3-Q1
print('IQR = ',IQR)

# Calculating the upper and lower limit
low_lim=Q1-(1.5*IQR)
up_lim=Q3+(1.5*IQR)
print('Upper limit = ',up_lim,'\nLower limit = ',low_lim)
# Out:
# IQR =  1.0
# Upper limit =  2.5
# Lower limit =  -1.5

# %%
# Creating a list of outliers

out2=[]
for x in df['SibSp']:
    if (x>up_lim or x<low_lim):
        out2.append(x)
out2
# Out:
# [3,
#  3,
#  4,
#  5,
#  3,
#  4,
#  5,
#  3,
#  3,
#  8,
#  4,
#  3,
#  8,
#  4,
#  8,
#  3,
#  4,
#  4,
#  4,
#  4,
#  8,
#  3,
#  3,
#  3,
#  5,
#  3,
#  4,
#  4,
#  3,
#  5,
#  4,
#  3,
#  4,
#  8,
#  4,
#  3,
#  8,
#  4,
#  8]

# %%
# Finding index values of outliers

df.loc[(df['SibSp']>up_lim ) | (df['SibSp']<low_lim)].index
# Out:
# Int64Index([ 25,  28,  51,  60,  64,  69,  72,  86,  89, 160, 172, 177, 181,
#             183, 202, 230, 234, 262, 267, 279, 325, 342, 375, 410, 481, 486,
#             542, 543, 635, 684, 687, 727, 788, 793, 814, 820, 847, 851, 864],
#            dtype='int64', name='PassengerId')

# %%
# Removing the outliers

df.drop([25,  28,  51,  60,  64,  69,  72,  86,  89, 160, 172, 177, 181,
            183, 202, 230, 234, 262, 267, 279, 325, 342, 375, 410, 481, 486,
            542, 543, 635, 684, 687, 727, 788, 793, 814, 820, 847, 851, 864],inplace=True)

# %%
# Boxplot of 'SibSp' after removing outliers

plt.boxplot(df['SibSp'])
plt.show()

# %% [markdown]
# **Insight : 39 rows were removed from the dataset**

# %% [markdown]
# ## **Fare**

# %%
# Calculating percentiles

Q1 = np.percentile(df['Fare'],25,interpolation='midpoint')
Q2 = np.percentile(df['Fare'],50,interpolation='midpoint')
Q3 = np.percentile(df['Fare'],75,interpolation='midpoint')
print('Q1 = ',Q1,'\nQ2 = ',round(Q2,2),'\nQ3 = ',Q3)
# Out:
# Q1 =  7.8958
# Q2 =  13.0
# Q3 =  27.75

# %%
# Calculating inter quartile range

IQR=Q3-Q1
print('IQR = ',IQR)

# Cculating the upper and lower limit

low_lim=Q1-(1.5*IQR)
up_lim=Q3+(1.5*IQR)
print('Upper limit = ',up_lim,'\nLower limit = ',round(low_lim,2))
# Out:
# IQR =  19.8542
# Upper limit =  57.5313
# Lower limit =  -21.89

# %%
# Creating a list of outliers

outl3=[]
for x in df['Fare']:
    if (x>up_lim or x<low_lim):
        outl3.append(x)
outl3
# Out:
# [71.2833,
#  146.5208,
#  82.1708,
#  76.7292,
#  80.0,
#  83.475,
#  73.5,
#  61.175,
#  63.3583,
#  77.2875,
#  247.5208,
#  73.5,
#  77.2875,
#  79.2,
#  66.6,
#  61.3792,
#  113.275,
#  76.2917,
#  90.0,
#  83.475,
#  90.0,
#  79.2,
#  86.5,
#  512.3292,
#  79.65,
#  135.6333,
#  78.85,
#  91.0792,
#  247.5208,
#  110.8833,
#  108.9,
#  83.1583,
#  262.375,
#  164.8667,
#  134.5,
#  135.6333,
#  57.9792,
#  153.4625,
#  133.65,
#  66.6,
#  134.5,
#  69.3,
#  135.6333,
#  82.1708,
#  211.5,
#  227.525,
#  73.5,
#  120.0,
#  113.275,
#  90.0,
#  120.0,
#  81.8583,
#  89.1042,
#  91.0792,
#  90.0,
#  78.2667,
#  151.55,
#  86.5,
#  108.9,
#  59.4,
#  93.5,
#  57.9792,
#  221.7792,
#  106.425,
#  71.0,
#  106.425,
#  110.8833,
#  227.525,
#  79.65,
#  110.8833,
#  79.65,
#  78.2667,
#  153.4625,
#  65.0,
#  77.9583,
#  69.3,
#  76.7292,
#  73.5,
#  133.65,
#  73.5,
#  512.3292,
#  76.7292,
#  211.3375,
#  110.8833,
#  227.525,
#  151.55,
#  227.525,
#  211.3375,
#  512.3292,
# ...

# %%
# Finding index values of outliers

idx = df.loc[(df['Fare']>up_lim ) | (df['Fare']<low_lim)].index
idx
# Out:
# Int64Index([  2,  32,  35,  53,  62,  63,  73,  93,  98, 103,
#             ...
#             760, 764, 766, 780, 790, 803, 821, 836, 850, 857],
#            dtype='int64', name='PassengerId', length=102)

# %%
# Removing the outliers

df.drop(idx,inplace=True)

# %%
# Boxplot of 'Fare' after removing outliers

plt.boxplot(df['Fare'])
plt.show()

# %% [markdown]
# **Insight : 102 rows were removed from the dataset**

# %% [markdown]
# ## **Min Max scaling on the feature set (Take ‘Survived’ as target)**

# %%
df.dtypes
# Out:
# Survived      int64
# Pclass        int64
# Name         object
# Sex          object
# Age         float64
# SibSp         int64
# Parch         int64
# Ticket       object
# Fare        float64
# Embarked     object
# dtype: object

# %%
# Dropping 'Name' and 'Ticket' as it contains no unique values

df.drop('Name', inplace=True, axis=1)
df.drop('Ticket', inplace=True, axis=1)
df
# Out:
#              Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# PassengerId
# 1                   0       3    male  22.0      1      0   7.2500        S
# 3                   1       3  female  26.0      0      0   7.9250        S
# 4                   1       1  female  35.0      1      0  53.1000        S
# 5                   0       3    male  35.0      0      0   8.0500        S
# 6                   0       3    male  28.0      0      0   8.4583        Q
# ...               ...     ...     ...   ...    ...    ...      ...      ...
# 887                 0       2    male  27.0      0      0  13.0000        S
# 888                 1       1  female  19.0      0      0  30.0000        S
# 889                 0       3  female  28.0      1      2  23.4500        S
# 890                 1       1    male  26.0      0      0  30.0000        C
# 891                 0       3    male  32.0      0      0   7.7500        Q
#
# [684 rows x 8 columns]

# %%
# One hot encoding

df = pd.get_dummies(df)
df
# Out:
#              Survived  Pclass   Age  SibSp  Parch     Fare  Sex_female  \
# PassengerId
# 1                   0       3  22.0      1      0   7.2500           0
# 3                   1       3  26.0      0      0   7.9250           1
# 4                   1       1  35.0      1      0  53.1000           1
# 5                   0       3  35.0      0      0   8.0500           0
# 6                   0       3  28.0      0      0   8.4583           0
# ...               ...     ...   ...    ...    ...      ...         ...
# 887                 0       2  27.0      0      0  13.0000           0
# 888                 1       1  19.0      0      0  30.0000           1
# 889                 0       3  28.0      1      2  23.4500           1
# 890                 1       1  26.0      0      0  30.0000           0
# 891                 0       3  32.0      0      0   7.7500           0
#
#              Sex_male  Embarked_C  Embarked_Q  Embarked_S
# PassengerId
# ...

# %%
# Splitting into independent and dependent variable

y= df['Survived']
x = df.drop(['Survived','Fare'],axis=1)

# Splitting

from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x, y, random_state=42, test_size = 0.25)

# Linear model

from sklearn import linear_model
lr = linear_model.LinearRegression()
model = lr.fit(x_train, y_train)
predictions = model.predict(x_test)

# Mean squared error

from sklearn.metrics import mean_squared_error
print("MSE is: ", mean_squared_error(y_test,predictions))
from sklearn.metrics import r2_score
print("R-squared value is: ",r2_score(y_test,predictions))
# Out:
# MSE is:  0.14730723756959
# R-squared value is:  0.3626204596371144

# %%
df = pd.DataFrame(data={'Predicted value':predictions,'Actual Value':y_test})
df
# Out:
#              Predicted value  Actual Value
# PassengerId
# 655                 0.722773             0
# 309                 0.349786             0
# 283                 0.151422             0
# 155                 0.080116             0
# 877                 0.127653             0
# ...                      ...           ...
# 842                 0.337849             0
# 214                 0.254659             0
# 444                 0.760507             1
# 785                 0.097942             0
# 566                 0.117214             0
#
# [171 rows x 2 columns]

# %%
# min max scaling

from sklearn import preprocessing
min_max=preprocessing.MinMaxScaler(feature_range=(0,1))
x=min_max.fit_transform(x)
x=pd.DataFrame(x)
x.describe()
# Out:
#                 0           1           2           3           4           5  \
# count  684.000000  684.000000  684.000000  684.000000  684.000000  684.000000
# mean     0.752193    0.502207    0.135965    0.044591    0.309942    0.690058
# std      0.357408    0.185072    0.250491    0.125948    0.462808    0.462808
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.500000    0.392157    0.000000    0.000000    0.000000    0.000000
# 50%      1.000000    0.490196    0.000000    0.000000    0.000000    1.000000
# 75%      1.000000    0.588235    0.000000    0.000000    1.000000    1.000000
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#                 6           7           8
# count  684.000000  684.000000  684.000000
# mean     0.146199    0.099415    0.754386
# std      0.353564    0.299438    0.430766
# min      0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    1.000000
# ...

# %%
# After min max scaling

x_train,x_test,y_train,y_test = train_test_split(x, y, random_state=42, test_size = 0.25)
lr = linear_model.LinearRegression()
model = lr.fit(x_train, y_train)
predictions = model.predict(x_test)
print("MSE is: ", mean_squared_error(y_test,predictions))
print("R-squared value is: ",r2_score(y_test,predictions))
# Out:
# MSE is:  0.14730723756959002
# R-squared value is:  0.3626204596371143

# %%
df = pd.DataFrame(data={'Predicted value':predictions,'Actual Value':y_test})
df
# Out:
#              Predicted value  Actual Value
# PassengerId
# 655                 0.722773             0
# 309                 0.349786             0
# 283                 0.151422             0
# 155                 0.080116             0
# 877                 0.127653             0
# ...                      ...           ...
# 842                 0.337849             0
# 214                 0.254659             0
# 444                 0.760507             1
# 785                 0.097942             0
# 566                 0.117214             0
#
# [171 rows x 2 columns]

# %% [markdown]
# # Conclusion : **We can see that the MSE and R-Squared value before and after  using Min Max Scaling method are the same**
